# %%
#%pip install qiskit qiskit-aer

# %%
from qiskit import *

# %%
circuit = QuantumCircuit(2,2) #q0, q1, c2 oluştu

# %%
#quantumRegister = QuantumRegister(2)
#classicalRegister = ClassicalRegister(2)

# %%
#circuit = QuantumCircuit(quantumRegister, classicalRegister)

# %%
circuit.draw()
# Out:
#
# q_0:
#
# q_1:
#
# c: 2/

# %%
# %matplotlib inline

# %%
#%pip install pylatexenc matplotlib

# %%
circuit.draw(output='mpl')

# %%
# entangeld

# %%
circuit.h(0) # q0 süperpozisyona alında

# %%
circuit.draw(output = 'mpl')

# %%
circuit.cx(0,1) # 0-> control qubit, 1-> target qubit

# %%
circuit.draw(output='mpl')

# %%
circuit.measure([0,1],[0,1])

# %%
circuit.draw(output='mpl')

# %%
from qiskit_aer import Aer

# %%
simulator = Aer.get_backend('qasm_simulator')

# %%
job = simulator.run(circuit, short=1024)

# %%
result = job.result()

# %%
counts = result.get_counts()
print("Ölçüm Sonuçları:", counts)
# Out:
# Ölçüm Sonuçları: {'00': 491, '11': 533}

# %%
from qiskit.visualization import plot_histogram
import matplotlib.pyplot as plt

# Önceki adımda elde ettiğiniz 'counts' verisini buraya veriyoruz
# Örn: counts = {'00': 512, '11': 512}
plot_histogram(counts)
